# %% [markdown]
# <a href="https://colab.research.google.com/github/arizonaCameraLab/computationalImaging/blob/master/samplingDesign/DefocusEstimation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple defocus parameter estimation
# ##David Brady
# ##University of Arizona
# ##December 2023

# %% [markdown]
# This notebook presents a simple neural estimator to evaluate the defocus of images. The PSF is modeled as a gaussian, defocus images are convolved with the Gaussian filter with a blur between 0 and 3 pixels. The defocus paramter is $\frac{\sigma}{3}$, randomly assigned on $[0,1]$.
#
# The neural network consists of 3 convolutional layers with normalization and maxpooling followed by a densely connected layer with linear activation to estimate the defocus.

# %% [markdown]
# ### Python modules

# %%
import numpy as np
import matplotlib.pyplot as plt
from  scipy.ndimage import gaussian_filter as gf
# %matplotlib inline
plt.rcParams['figure.figsize'] = [30, 10]
plt.rcParams.update({'font.size': 22})
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model, Sequential
import cv2

# %% [markdown]
# # Neural Estimation

# %% [markdown]
# ## Image database

# %%
# load the mnist dataset of characters


(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# defocus values
y_train=np.random.random(len(y_train))
y_test=np.random.random(len(y_test))
x_train=np.mean(x_train,axis=3)/255.0
x_test=np.mean(x_test,axis=3)/255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 9s 0us/step

# %%
y_test.shape
# Out:
# (10000,)

# %%
plt.imshow(x_train[32],cmap='gray')

# %% [markdown]
# ###  prepare training data

# %%
g_test=np.zeros(np.shape(x_test))
g_train=np.zeros(np.shape(x_train))
for pop in range(np.shape(x_test)[0]):
  g_test[pop,:,:]= gf(x_test[pop,:,:],3*y_test[pop])
for pop in range(np.shape(x_train)[0]):
  g_train[pop,:,:]=gf(x_train[pop,:,:],3*y_train[pop])

# %%
plt.figure(figsize=(10,5))
images=np.random.randint(0,len(y_train),9)
for pop in range(9):
  plt.subplot(3,6, 2*pop+1)
  plt.imshow(x_train[images[pop]], cmap='gray')
  plt.axis('off')
  plt.subplot(3,6, 2*pop+2)
  plt.imshow(g_train[images[pop]],cmap='gray')
  plt.axis('off')
  plt.savefig('defocusExamples.png')

# %%
g_train = np.reshape(g_train, (len(y_train), 32, 32, 1))
g_test = np.reshape(g_test, (len(y_test), 32, 32, 1))

# %% [markdown]
# ### Estimation model

# %%
inputs=keras.Input(shape=(32,32,1))

x = layers.Conv2D(16, (5, 5), strides=1, activation="gelu", padding="same")(inputs)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(16, (4, 4), strides=2, activation="gelu", padding="same")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(32, (3, 3), strides=2, activation="gelu", padding="same")(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Dropout(0.3)(x)
x = layers.Flatten()(x)
x = layers.Dense(16, activation="gelu")(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="linear")(x)

defocus = Model(inputs, outputs)
defocus.compile(optimizer='adam', loss='mean_squared_error')
defocus.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 16)        416
#
#  batch_normalization (Batch  (None, 32, 32, 16)        64
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 16)        4112
#
#  batch_normalization_1 (Bat  (None, 16, 16, 16)        64
#  chNormalization)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 32)          4640
#
#  max_pooling2d (MaxPooling2  (None, 4, 4, 32)          0
#  D)
#
#  dropout (Dropout)           (None, 4, 4, 32)          0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 16)                8208
#
#  batch_normalization_2 (Bat  (None, 16)                64
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 17585 (68.69 KB)
# Trainable params: 17489 (68.32 KB)
# Non-trainable params: 96 (384.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
defocus.fit(
    x=g_train,
    y=y_train,
    epochs=100,
    batch_size=128,
    shuffle=True,
    validation_data=(g_test, y_test),
)
# Out:
# Epoch 1/100
# 391/391 [==============================] - 16s 8ms/step - loss: 0.8699 - val_loss: 0.1418
# Epoch 2/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.1373 - val_loss: 0.0342
# Epoch 3/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0447 - val_loss: 0.0226
# Epoch 4/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0242 - val_loss: 0.0147
# Epoch 5/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0187 - val_loss: 0.0101
# Epoch 6/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0167 - val_loss: 0.0096
# Epoch 7/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0156 - val_loss: 0.0104
# Epoch 8/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0147 - val_loss: 0.0070
# Epoch 9/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0139 - val_loss: 0.0065
# Epoch 10/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0134 - val_loss: 0.0064
# Epoch 11/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0129 - val_loss: 0.0069
# Epoch 12/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0123 - val_loss: 0.0055
# Epoch 13/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0119 - val_loss: 0.0049
# Epoch 14/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0116 - val_loss: 0.0081
# Epoch 15/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0112 - val_loss: 0.0040
# Epoch 16/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0110 - val_loss: 0.0050
# Epoch 17/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0108 - val_loss: 0.0044
# Epoch 18/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0105 - val_loss: 0.0036
# Epoch 19/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0103 - val_loss: 0.0054
# Epoch 20/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0099 - val_loss: 0.0037
# Epoch 21/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0099 - val_loss: 0.0050
# Epoch 22/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0097 - val_loss: 0.0032
# Epoch 23/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0096 - val_loss: 0.0041
# Epoch 24/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0094 - val_loss: 0.0034
# Epoch 25/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0094 - val_loss: 0.0038
# Epoch 26/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0094 - val_loss: 0.0039
# Epoch 27/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0092 - val_loss: 0.0028
# Epoch 28/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0091 - val_loss: 0.0053
# Epoch 29/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0093 - val_loss: 0.0026
# Epoch 30/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0090 - val_loss: 0.0030
# Epoch 31/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0033
# Epoch 32/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0091 - val_loss: 0.0024
# Epoch 33/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0088 - val_loss: 0.0026
# Epoch 34/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0029
# Epoch 35/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0089 - val_loss: 0.0031
# Epoch 36/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0088 - val_loss: 0.0025
# Epoch 37/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0088 - val_loss: 0.0030
# Epoch 38/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0088 - val_loss: 0.0030
# Epoch 39/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0032
# Epoch 40/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0041
# Epoch 41/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0085 - val_loss: 0.0031
# Epoch 42/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0085 - val_loss: 0.0023
# Epoch 43/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0022
# Epoch 44/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0086 - val_loss: 0.0034
# Epoch 45/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0087 - val_loss: 0.0023
# Epoch 46/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0085 - val_loss: 0.0021
# Epoch 47/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0085 - val_loss: 0.0024
# Epoch 48/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0029
# Epoch 49/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0021
# Epoch 50/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0033
# Epoch 51/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0025
# Epoch 52/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0083 - val_loss: 0.0023
# Epoch 53/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0082 - val_loss: 0.0030
# Epoch 54/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0083 - val_loss: 0.0032
# Epoch 55/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0082 - val_loss: 0.0022
# Epoch 56/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0083 - val_loss: 0.0026
# Epoch 57/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0083 - val_loss: 0.0025
# Epoch 58/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0081 - val_loss: 0.0030
# Epoch 59/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0081 - val_loss: 0.0026
# Epoch 60/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0081 - val_loss: 0.0020
# Epoch 61/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0081 - val_loss: 0.0045
# Epoch 62/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0080 - val_loss: 0.0022
# Epoch 63/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0080 - val_loss: 0.0024
# Epoch 64/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0080 - val_loss: 0.0022
# Epoch 65/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0080 - val_loss: 0.0022
# Epoch 66/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0079 - val_loss: 0.0022
# Epoch 67/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0080 - val_loss: 0.0030
# Epoch 68/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0079 - val_loss: 0.0020
# Epoch 69/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0029
# Epoch 70/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0078 - val_loss: 0.0032
# Epoch 71/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0027
# Epoch 72/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0023
# Epoch 73/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0019
# Epoch 74/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0079 - val_loss: 0.0032
# Epoch 75/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0078 - val_loss: 0.0020
# Epoch 76/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0079 - val_loss: 0.0022
# Epoch 77/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0022
# Epoch 78/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0019
# Epoch 79/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 80/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0075 - val_loss: 0.0025
# Epoch 81/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0018
# Epoch 82/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0028
# Epoch 83/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 84/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0078 - val_loss: 0.0025
# Epoch 85/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 86/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0077 - val_loss: 0.0020
# Epoch 87/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 88/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0077 - val_loss: 0.0023
# Epoch 89/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0075 - val_loss: 0.0018
# Epoch 90/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0075 - val_loss: 0.0023
# Epoch 91/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0019
# Epoch 92/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0021
# Epoch 93/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0076 - val_loss: 0.0025
# Epoch 94/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0074 - val_loss: 0.0022
# Epoch 95/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0020
# Epoch 96/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0076 - val_loss: 0.0024
# Epoch 97/100
# 391/391 [==============================] - 3s 7ms/step - loss: 0.0075 - val_loss: 0.0016
# Epoch 98/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0074 - val_loss: 0.0025
# Epoch 99/100
# 391/391 [==============================] - 2s 6ms/step - loss: 0.0076 - val_loss: 0.0016
# Epoch 100/100
# 391/391 [==============================] - 3s 6ms/step - loss: 0.0074 - val_loss: 0.0019

# %%
defocus.predict(g_test[0:10,:,:,:]).reshape(10)
# Out:
# 1/1 [==============================] - 0s 167ms/step
# array([0.27051967, 0.3656418 , 0.9350143 , 0.08392179, 0.72627467,
#        0.322183  , 0.7407231 , 0.93220735, 0.14900467, 0.07696596],
#       dtype=float32)

# %%
y_test[0:10]
# Out:
# array([0.26913183, 0.37055271, 0.95067467, 0.0249277 , 0.73995618,
#        0.31619357, 0.82499943, 0.97420385, 0.11684437, 0.04794359])

# %%
images=np.random.randint(0,len(y_train),1000)
plt.scatter(y_train[images],defocus.predict(g_train[images,:,:,:]).reshape(1000))
plt.xlabel('True defocus')
plt.ylabel('Predicted defocus')
plt.savefig('defocusAccuracy.png')
# Out:
# 32/32 [==============================] - 0s 3ms/step
